# %%
pwd
# Out:
# 'W:\\DS\\content\\yolov5'

# %%
ls
# Out:
#  Volume in drive W is Work
#  Volume Serial Number is F8B8-87CD
#
#  Directory of W:\DS\content\yolov5
#
# 2021/12/22  18:28    <DIR>          .
# 2021/12/22  18:28    <DIR>          ..
# 2021/12/22  15:29             3,684 .dockerignore
# 2021/12/22  15:30    <DIR>          .git
# 2021/12/22  15:29                75 .gitattributes
# 2021/12/22  15:29    <DIR>          .github
# 2021/12/22  15:29             3,964 .gitignore
# 2021/12/22  18:26    <DIR>          .ipynb_checkpoints
# 2021/12/22  15:29             1,553 .pre-commit-config.yaml
# 2021/12/22  15:30    <DIR>          __pycache__
# 2021/12/22  15:29             4,991 CONTRIBUTING.md
# 2021/12/22  15:29    <DIR>          data
# 2021/12/22  15:29            12,360 detect.py
# 2021/12/22  15:29             2,163 Dockerfile
# 2021/12/22  15:29            20,633 export.py
# 2021/12/22  15:29             6,381 hubconf.py
# 2021/12/22  15:29            35,127 LICENSE
# 2021/12/22  15:30    <DIR>          models
# 2021/12/22  15:29            14,746 README.md
# 2021/12/22  15:29               892 requirements.txt
# 2021/12/22  17:45    <DIR>          runs
# 2021/12/22  15:29               923 setup.cfg
# 2021/09/10  15:52    <DIR>          test
# 2021/12/22  17:50    <DIR>          test_resize
# 2021/12/22  15:29            32,709 train.py
# 2021/12/22  15:29            57,002 tutorial.ipynb
# 2021/12/22  18:28             1,491 Untitled.ipynb
# 2021/12/22  15:30    <DIR>          utils
# 2021/12/22  15:29            17,995 val.py
# 2021/12/22  15:30        14,698,491 yolov5s.pt
# 2021/12/22  17:47        52,063,620 評価用.zip
#               19 File(s)     66,978,800 bytes
#               12 Dir(s)  86,748,934,144 bytes free

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
from pathlib import Path
from xml.dom.minidom import parse
from shutil import copyfile
import os

# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: matplotlib>=3.2.2 in c:\users\judge\anaconda3\envs\pytorch\lib\site-packages (from -r requirements.txt (line 4)) (3.4.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\judge\anaconda3\envs\pytorch\lib\site-packages (from -r requirements.txt (line 5)) (1.19.2)
# Requirement already satisfied: opencv-python>=4.1.2 in c:\users\judge\anaconda3\envs\pytorch\lib\site-packages (from -r requirements.txt (line 6)) (4.5.1.48)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\judge\anaconda3\envs\pytorch\lib\site-packages (from -r requirements.txt (line 7)) (8.0.1)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\judge\anaconda3\envs\pytorch\lib\site-packages (from -r requirements.txt (line 10)) (1.7.0)
# Requirement already satisfied: torch>=1.7.0 in c:\users\judge\anaconda3\envs\pytorch\lib\site-packages (from -r requirements.txt (line 11)) (1.7.1)
# Requirement already satisfied: torchvision>=0.8.1 in c:\users\judge\anaconda3\envs\pytorch\lib\site-packages (from -r requirements.txt (line 12)) (0.8.2)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\judge\anaconda3\envs\pytorch\lib\site-packages (from -r requirements.txt (line 20)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\judge\anaconda3\envs\pytorch\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\judge\anaconda3\envs\pytorch\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\judge\anaconda3\envs\pytorch\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (2.8.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\judge\anaconda3\envs\pytorch\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (2.4.7)
# Requirement already satisfied: pytz>=2017.3 in c:\users\judge\anaconda3\envs\pytorch\lib\site-packages (from pandas>=1.1.4->-r requirements.txt (line 20)) (2021.1)
# Collecting PyYAML>=5.3.1
#   Downloading PyYAML-6.0-cp37-cp37m-win_amd64.whl (153 kB)
# Collecting requests>=2.23.0
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\judge\anaconda3\envs\pytorch\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (2020.12.5)
# Collecting seaborn>=0.11.0
#   Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
# Collecting tensorboard>=2.4.1
#   Downloading tensorboard-2.7.0-py3-none-any.whl (5.8 MB)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\judge\anaconda3\envs\pytorch\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (51.0.0.post20201207)
# Requirement already satisfied: wheel>=0.26 in c:\users\judge\anaconda3\envs\pytorch\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.36.2)
# Requirement already satisfied: typing_extensions in c:\users\judge\anaconda3\envs\pytorch\lib\site-packages (from torch>=1.7.0->-r requirements.txt (line 11)) (3.7.4.3)
# Collecting tqdm>=4.41.0
#   Downloading tqdm-4.62.3-py2.py3-none-any.whl (76 kB)
# Requirement already satisfied: colorama in c:\users\judge\anaconda3\envs\pytorch\lib\site-packages (from tqdm>=4.41.0->-r requirements.txt (line 13)) (0.4.4)
# Collecting absl-py>=0.4
#   Downloading absl_py-1.0.0-py3-none-any.whl (126 kB)
# Requirement already satisfied: six in c:\users\judge\anaconda3\envs\pytorch\lib\site-packages (from absl-py>=0.4->tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.15.0)
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.9-py3-none-any.whl (39 kB)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.3.3-py2.py3-none-any.whl (155 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting grpcio>=1.24.3
#   Downloading grpcio-1.43.0-cp37-cp37m-win_amd64.whl (3.3 MB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.6-py3-none-any.whl (97 kB)
# Collecting importlib-metadata>=4.4
#   Downloading importlib_metadata-4.10.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\judge\anaconda3\envs\pytorch\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.4.1->-r requirements.txt (line 16)) (3.4.0)
# Collecting protobuf>=3.6.0
#   Downloading protobuf-3.19.1-cp37-cp37m-win_amd64.whl (896 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.8-py3-none-any.whl (39 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
# Collecting werkzeug>=0.11.15
#   Downloading Werkzeug-2.0.2-py3-none-any.whl (288 kB)
# Collecting thop
#   Downloading thop-0.0.31.post2005241907-py3-none-any.whl (8.7 kB)
# Installing collected packages: urllib3, pyasn1, idna, charset-normalizer, rsa, requests, pyasn1-modules, oauthlib, cachetools, requests-oauthlib, importlib-metadata, google-auth, werkzeug, tensorboard-plugin-wit, tensorboard-data-server, protobuf, markdown, grpcio, google-auth-oauthlib, absl-py, tqdm, thop, tensorboard, seaborn, PyYAML
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 2.0.0
#     Uninstalling importlib-metadata-2.0.0:
#       Successfully uninstalled importlib-metadata-2.0.0
# Successfully installed PyYAML-6.0 absl-py-1.0.0 cachetools-4.2.4 charset-normalizer-2.0.9 google-auth-2.3.3 google-auth-oauthlib-0.4.6 grpcio-1.43.0 idna-3.3 importlib-metadata-4.10.0 markdown-3.3.6 oauthlib-3.1.1 protobuf-3.19.1 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-2.26.0 requests-oauthlib-1.3.0 rsa-4.8 seaborn-0.11.2 tensorboard-2.7.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.0 thop-0.0.31.post2005241907 tqdm-4.62.3 urllib3-1.26.7 werkzeug-2.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python detect.py --source ./test_resize/ --img-size 416 --conf 0.4 --weights runs/train/exp2/weights/best.pt
# Out:
# detect: weights=['runs/train/exp2/weights/best.pt'], source=./test_resize/, imgsz=[416, 416], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  v6.0-155-gdc54ed5 torch 1.7.1 CUDA:0 (NVIDIA GeForce GTX 1080 Ti, 11264MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/27 W:\DS\content\yolov5\test_resize\IMG_7947.jpg: 416x416 3 helmets, Done. (0.009s)
# image 2/27 W:\DS\content\yolov5\test_resize\IMG_7948.jpg: 416x416 2 helmets, Done. (0.008s)
# image 3/27 W:\DS\content\yolov5\test_resize\IMG_7949.jpg: 416x416 2 helmets, Done. (0.008s)
# image 4/27 W:\DS\content\yolov5\test_resize\IMG_7950.jpg: 416x416 5 helmets, Done. (0.006s)
# image 5/27 W:\DS\content\yolov5\test_resize\IMG_7951.jpg: 416x416 4 helmets, Done. (0.006s)
# image 6/27 W:\DS\content\yolov5\test_resize\IMG_7952.jpg: 416x416 2 helmets, Done. (0.007s)
# image 7/27 W:\DS\content\yolov5\test_resize\IMG_7953.jpg: 416x416 1 helmet, Done. (0.007s)
# image 8/27 W:\DS\content\yolov5\test_resize\IMG_7954.jpg: 416x416 1 helmet, Done. (0.009s)
# image 9/27 W:\DS\content\yolov5\test_resize\IMG_7955.jpg: 416x416 4 helmets, Done. (0.007s)
# image 10/27 W:\DS\content\yolov5\test_resize\IMG_7956.jpg: 416x416 1 head, 4 helmets, Done. (0.008s)
# image 11/27 W:\DS\content\yolov5\test_resize\IMG_7957.jpg: 416x416 2 heads, 1 helmet, Done. (0.009s)
# image 12/27 W:\DS\content\yolov5\test_resize\IMG_7958.jpg: 416x416 1 head, 4 helmets, Done. (0.006s)
# image 13/27 W:\DS\content\yolov5\test_resize\IMG_7959.jpg: 416x416 1 head, 4 helmets, Done. (0.007s)
# image 14/27 W:\DS\content\yolov5\test_resize\IMG_7960.jpg: 416x416 1 head, 4 helmets, Done. (0.006s)
# image 15/27 W:\DS\content\yolov5\test_resize\IMG_7961.jpg: 416x416 1 head, 4 helmets, Done. (0.009s)
# image 16/27 W:\DS\content\yolov5\test_resize\IMG_7962.jpg: 416x416 2 helmets, Done. (0.006s)
# image 17/27 W:\DS\content\yolov5\test_resize\IMG_7963.jpg: 416x416 2 helmets, Done. (0.005s)
# image 18/27 W:\DS\content\yolov5\test_resize\IMG_7964.jpg: 416x416 1 head, Done. (0.007s)
# image 19/27 W:\DS\content\yolov5\test_resize\IMG_7965.jpg: 416x416 1 helmet, Done. (0.007s)
# image 20/27 W:\DS\content\yolov5\test_resize\IMG_7966.jpg: 416x416 1 helmet, Done. (0.009s)
# image 21/27 W:\DS\content\yolov5\test_resize\IMG_7967.jpg: 416x416 1 helmet, Done. (0.006s)
# image 22/27 W:\DS\content\yolov5\test_resize\IMG_7968.jpg: 416x416 1 helmet, Done. (0.006s)
# image 23/27 W:\DS\content\yolov5\test_resize\IMG_7969.jpg: 416x416 1 helmet, Done. (0.006s)
# image 24/27 W:\DS\content\yolov5\test_resize\IMG_7970.jpg: 416x416 2 helmets, Done. (0.009s)
# image 25/27 W:\DS\content\yolov5\test_resize\IMG_7971.jpg: 416x416 3 helmets, Done. (0.012s)
# image 26/27 W:\DS\content\yolov5\test_resize\IMG_7972.jpg: 416x416 3 helmets, Done. (0.019s)
# image 27/27 W:\DS\content\yolov5\test_resize\IMG_7973.jpg: 416x416 3 helmets, Done. (0.012s)
# Speed: 0.4ms pre-process, 8.0ms inference, 1.7ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs\detect\exp7

# %%
# display detected images
from IPython.display import Image

# %%
from glob import glob
import matplotlib.pyplot as plt
testfiles = glob('runs/detect/exp7/*')

img = plt.imread(testfiles[5]) 
plt.imshow(img)    
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
